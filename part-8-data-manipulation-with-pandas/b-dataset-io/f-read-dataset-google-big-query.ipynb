# %%
import pandas as pd

query = """
SELECT * FROM `bigquery-public-data.covid19_jhu_csse_eu.summary` LIMIT 1000;
"""

df_covid19_eu_summary = pd.read_gbq(query, project_id="XXXXXXXX")

print("Dataframe: \n", df_covid19_eu_summary)
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=725825577420-unm2gnkiprugilg743tkbig250f4sfsj.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fbigquery&state=I81X5khBzIOwbaYKZyT0wX6CpcRacW&prompt=consent&access_type=offline
# ---------------------------------------------------------------------------
# InvalidGrantError                         Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/pydata_google_auth/auth.py in get_user_credentials(scopes, client_id, client_secret, credentials_cache, use_local_webserver, auth_local_webserver)
#     265             else:
# --> 266                 credentials = app_flow.run_console()
#     267         except oauthlib.oauth2.rfc6749.errors.OAuth2Error as exc:
#
# ~/.local/lib/python3.8/site-packages/google_auth_oauthlib/flow.py in run_console(self, authorization_prompt_message, authorization_code_message, **kwargs)
#     413
# --> 414         self.fetch_token(code=code)
#     415
#
# ~/.local/lib/python3.8/site-packages/google_auth_oauthlib/flow.py in fetch_token(self, **kwargs)
#     287         kwargs.setdefault("code_verifier", self.code_verifier)
# --> 288         return self.oauth2session.fetch_token(self.client_config["token_uri"], **kwargs)
#     289
#
# ~/.local/lib/python3.8/site-packages/requests_oauthlib/oauth2_session.py in fetch_token(self, token_url, code, authorization_response, body, auth, username, password, method, force_querystring, timeout, headers, verify, proxies, include_client_id, client_secret, **kwargs)
#     359
# --> 360         self._client.parse_request_body_response(r.text, scope=self.scope)
#     361         self.token = self._client.token
#
# /usr/lib/python3/dist-packages/oauthlib/oauth2/rfc6749/clients/base.py in parse_request_body_response(self, body, scope, **kwargs)
#     420         """
# --> 421         self.token = parse_token_response(body, scope=scope)
#     422         self.populate_token_attributes(self.token)
#
# /usr/lib/python3/dist-packages/oauthlib/oauth2/rfc6749/parameters.py in parse_token_response(body, scope)
#     430     params = OAuth2Token(params, old_scope=scope)
# --> 431     validate_token_parameters(params)
#     432     return params
#
# /usr/lib/python3/dist-packages/oauthlib/oauth2/rfc6749/parameters.py in validate_token_parameters(params)
#     437     if 'error' in params:
# --> 438         raise_from_error(params.get('error'), params)
#     439
#
# /usr/lib/python3/dist-packages/oauthlib/oauth2/rfc6749/errors.py in raise_from_error(error, params)
#     404         if cls.error == error:
# --> 405             raise cls(**kwargs)
#     406     raise CustomOAuth2Error(error=error, **kwargs)
#
# InvalidGrantError: (invalid_grant) Bad Request
#
# During handling of the above exception, another exception occurred:
#
# PyDataCredentialsError                    Traceback (most recent call last)
# <ipython-input-8-96e03abc4164> in <module>
#       5 """
#       6
# ----> 7 df_covid19_eu_summary = pd.read_gbq(query, project_id="4/1AY0e-g5XNUECl4-SY4TF_Fi6Ezr3KnY-CYz5OHF3r9Ur7l9JbuF6C0AJsBg")
#       8
#       9 print("Dataframe: \n", df_covid19_eu_summary)
#
# ~/.local/lib/python3.8/site-packages/pandas/io/gbq.py in read_gbq(query, project_id, index_col, col_order, reauth, auth_local_webserver, dialect, location, configuration, credentials, use_bqstorage_api, max_results, progress_bar_type)
#     180     # END: new kwargs
#     181
# --> 182     return pandas_gbq.read_gbq(
#     183         query,
#     184         project_id=project_id,
#
# ~/.local/lib/python3.8/site-packages/pandas_gbq/gbq.py in read_gbq(query, project_id, index_col, col_order, reauth, auth_local_webserver, dialect, location, configuration, credentials, use_bqstorage_api, max_results, verbose, private_key, progress_bar_type, dtypes)
#     839         raise ValueError("'{0}' is not valid for dialect".format(dialect))
#     840
# --> 841     connector = GbqConnector(
#     842         project_id,
#     843         reauth=reauth,
#
# ~/.local/lib/python3.8/site-packages/pandas_gbq/gbq.py in __init__(self, project_id, reauth, private_key, auth_local_webserver, dialect, location, credentials, use_bqstorage_api)
#     295         # Credentials were explicitly asked for, so don't use the cache.
#     296         if private_key or reauth or not self.credentials:
# --> 297             self.credentials, default_project = auth.get_credentials(
#     298                 private_key=private_key,
#     299                 project_id=project_id,
#
# ~/.local/lib/python3.8/site-packages/pandas_gbq/auth.py in get_credentials(private_key, project_id, reauth, auth_local_webserver)
#      40         )
#      41
# ---> 42     credentials, default_project_id = pydata_google_auth.default(
#      43         SCOPES,
#      44         client_id=CLIENT_ID,
#
# ~/.local/lib/python3.8/site-packages/pydata_google_auth/auth.py in default(scopes, client_id, client_secret, credentials_cache, use_local_webserver, auth_local_webserver)
#     102         return credentials, default_project
#     103
# --> 104     credentials = get_user_credentials(
#     105         scopes,
#     106         client_id=client_id,
#
# ~/.local/lib/python3.8/site-packages/pydata_google_auth/auth.py in get_user_credentials(scopes, client_id, client_secret, credentials_cache, use_local_webserver, auth_local_webserver)
#     266                 credentials = app_flow.run_console()
#     267         except oauthlib.oauth2.rfc6749.errors.OAuth2Error as exc:
# --> 268             raise exceptions.PyDataCredentialsError(
#     269                 "Unable to get valid credentials: {}".format(exc)
#     270             )
#
# PyDataCredentialsError: Unable to get valid credentials: (invalid_grant) Bad Request
