# %%
import pandas as pd
import numpy as np
import io
import pandas_profiling
import matplotlib.pyplot as plt

uncleared_raw = pd.read_csv("https://storage.googleapis.com/dqlab-dataset/uncleaned_raw.csv")
uncleared_raw.boxplot()
plt.show()
